# %%
import matplotlib.pyplot as plt
from typing import List

bar_width = 0.5
weeks = [f"W{x}" for x in range(1, 11)]
# stats = [
#     [10, 8, 6]
# ]

# stacks: List[List[int]] = [[], [], [], []]
# bottoms: List[List[int]] = [[], [], [], []]
# for evaluation in stats:
#     bottom = 0
#     for i in range(4):
#         stacks[i].append(evaluation[i])
#         bottoms[i].append(bottom)
#         bottom = evaluation[i] + bottom


x = range(len(weeks))

stacks = [
    [4.15, 4.01, 3.9, 4.08, 3.49, 3.85, 2.92, 2.86, 3.25, 2.9]
]
plt.bar(x, stacks[0], width=bar_width, color="blue")
# plt.bar(x, stacks[1], bottom=bottoms[1], width=bar_width, label='1 Criteria Met', color="orange")
# plt.bar(x, stacks[2], bottom=bottoms[2], width=bar_width, label='2 Criterias Met', color="yellow")
# plt.bar(x, stacks[3], bottom=bottoms[3], width=bar_width, label='3 Criterias Met', color="green")

plt.xlabel('Week')
plt.ylabel('Mean Hours Spent on Phone')
plt.title('Weekly Average Hours Spent on Phone')
plt.xticks(x, weeks)
plt.legend()
plt.show()
# Out:
# /var/folders/b5/jzcfggbs2d78y0xs2p72_ry40000gn/T/ipykernel_5817/3589334534.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
