# %%
print(3 / 0 > 3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(3 / 0 > 3)
#
# ZeroDivisionError: division by zero

# %%
# Short circuit evaluation.
print(3 < 6 or 3 / 0 > 0) # Gets short circuited because 3 < 6 gets evaluated to true.
print(3 > 6 or 3 / 0 > 0) # Does not get short circuited therefor 3 / 0 will get evaluated which throws a divide by 0 error.
# Out:
# True
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 print(3 < 6 or 3 / 0 > 0)
# ----> 2 print(3 > 6 or 3 / 0 > 0)
#
# ZeroDivisionError: division by zero

# %%
a = 5
b = 3
a,b = b,a
print(a,b, end=" vs ")
a = 5
b = 3
print(a,b)
# Out:
# 3 5 vs 5 3

# %%
import math

# String formatting
# a = math.pi
a = 1.23456789
print(a)

# Percentage formatting
print(format(a, "%"))
print(format(a, ".0%"))
print(format(a, ".00%"))

# Floating point formatting
print(format(a, ".01f"))
print(format(a, ".02f"))

# String interpolating formatting
print("hello {}".format("world!"))
print("hello {}".format(a))
print("hello {}".format(
    format(
        float(format(a, ".03f")),
        "%"
    )
))
print(f"hello {a}")
print("{:.2%}".format(0.75))
print(f'{a}')
print(f"""
    {a}
      """)
# <value>:<format>
print(f'''
    {a:.2f}
      ''')
# Out:
# 1.23456789
# 123.456789%
# 123%
# 1.2
# 1.23
# hello world!
# hello 1.23456789
# hello 123.500000%
# hello 1.23456789
# 75.00%
# 1.23456789
#
#     1.23456789
#
#
#     1.23
