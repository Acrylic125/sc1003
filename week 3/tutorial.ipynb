# %% [markdown]
# # Q1
# ## Problem
# What is the Python data type for each literal/expression below? Moreover, what is the resulting data value for each expression?
#
# ```python
# 1 / 2
# 1 // 2
# 1 > 2`
# True
# "True"
# 3 < 3 and 3/0 > 0
# 3/0 > 3 and 3 < 0
# 3 > 0 or 3/0 != 1
# 5 < 6 > 3
# ```
#
# ## Solution
# ```python
# 1 / 2 # 0.5, float
# 1 // 2 # 0, int
# 1 > 2` # Invalid syntax but if it is intended to be 1 > 2 then False, bool
# True # True, bool
# "True" # True, bool
# 3 < 3 and 3/0 > 0 # False, short circuit evaluation, bool
# 3/0 > 3 and 3 < 0 # Error, divide by zero
# 3 > 0 or 3/0 != 1 # True, short circuit evaluation, bool
# 5 < 6 > 3 # True, bool
# ```

# %% [markdown]
# # Q2
# ## Problem
# Consider the following Python program, for each line, from line1 to line6, state the output and briefly explain the reason.
#
# ```python
# a, b, c = 9, 10, 11
# print (5>a or b<8 or 20>c>9)      #line1
#
# a, b, c = 4, -1, 11
# c, b, a = a//2, int(c/3), b+c
# print(a,b,c)                      #line2
#
# a = 8 + 9
#
# if a > 8:
#     print ("bigger")              #line3
#     print("small")                #line4
# if a < 9:
#     print ("bigger")              #line5
# print("small")                    #line6
# ```
#
# ## Solutoon
# ```python
# a, b, c = 9, 10, 11
# # 5>a, 5 > 9 = False
# # b<8, 10<8 = False
# # 10>c and c>9, 10>11 and 11>9 = False
# print (5>a or b<8 or 20>c>9)      # False
#
# a, b, c = 4, -1, 11
# # a//2, c = 4//2 = 2
# # int(c/3), b = int(11/3) = 3
# # b+c, a = -1 + 11 = 10
# c, b, a = a//2, int(c/3), b+c
# print(a,b,c)                      # 10 3 2
#
# a = 8 + 9
#
# if a > 8:
#     print ("bigger")              # bigger
#     print("small")                # small
# if a < 9:
#     print ("bigger")              # *won't be reached.*
# print("small")                    # small
# ```

# %% [markdown]
# # Q3
# ## Problem
# What is the output of the following?
#
# ```python
# # Define the conditions
# is_admin = True
# is_logged_in = True
# has_permission = False
#
# # Define the boolean expression for access control
# access_granted = is_logged_in and (is_admin or has_permission)
#
# # Print the evaluation of the boolean expression
# if access_granted:
#     print("Access granted.")
# else:
#   print("Access denied.")
# ```
#
# ## Solution
# ```python
# # Define the conditions
# is_admin = True
# is_logged_in = True
# has_permission = False
#
# # Define the boolean expression for access control
# # True
# access_granted = is_logged_in and (is_admin or has_permission)
#
# # Print the evaluation of the boolean expression
# if access_granted:
#     print("Access granted.") # Access granted
# else:
#   print("Access denied.") # *Will not get printed.*
# ```

# %% [markdown]
# # Q4
# ## Problem
# Real-Life Example: Smart Home Security System
# A smart home security system uses boolean logic to determine whether to trigger an alarm based on various sensors and conditions. The system might include motion detectors, door/window sensors, and a time-based arming schedule.
# A time-based arming schedule is a feature in security systems where the system automatically arms and disarms itself at predefined times. This scheduling ensures that the security system is active when needed and inactive when it’s not necessary, such as when people are home and moving around freely.
#
# Based on the Scenario that should trigger an alarm if:
# Motion is detected AND
# The system is armed AND
# A door or window is open
# Write the Boolean expression to check if the alarm should be triggered.
#
# ## Solution
# ```python
# motion_is_detected and system_is_armed and (door_is_open or window_is_open)
# ```

# %% [markdown]
# # Q5
# What is the output of the following program?
#
# ## Problem
# ```python
# # Define user roles and request content
# user_role = "admin"
# request_content = "delete record"
#
# # Define conditions for access
# is_admin = (user_role == "admin")
# is_manager = (user_role == "manager")
# contains_delete = ("delete" in request_content)
# contains_record = ("record" in request_content)
#
# # Define the boolean expression for access control
# access_granted = (is_admin or is_manager) and contains_delete and contains_record
#
# # Print the evaluation of the boolean expression
# if access_granted:
#     print("Access granted.")
# else:
#     print("Access denied.")
# ```
#
# ## Solution
# ```python
# # Define user roles and request content
# user_role = "admin"
# request_content = "delete record"
#
# # Define conditions for access
# is_admin = (user_role == "admin") # True
# is_manager = (user_role == "manager") # False
# contains_delete = ("delete" in request_content) # True
# contains_record = ("record" in request_content) # True
#
# # Define the boolean expression for access control
# # (True) and True and True
# access_granted = (is_admin or is_manager) and contains_delete and contains_record
#
# # Print the evaluation of the boolean expression
# # True
# if access_granted:
#     print("Access granted.") # Access granted.
# else:
#     print("Access denied.") # *Won't reach*
# ```

# %% [markdown]
# # Q6
#
# ## Problem
# What is the output of the following program?
#
# ```python
# # List of items to categorize
# items = ["apple", "carrot", "durian","tomato","banana", "spinach", "orange", "broccoli"]
# # List of known fruits and vegetables
# known_fruits = ["apple", "banana", "orange"]
# known_vegetables = ["carrot", "spinach", "broccoli"]
#
# num_fruit=num_veg=0
#
# # Read each item and categorize it
# for item in items:
#     if item in known_fruits:
#         num_fruit=num_fruit+1
#     elif item in known_vegetables:
#         num_veg = num_veg+1
#     else:
#         print(f"Item '{item}' is unknown and will not be categorized.")
#
# # Output the categorized lists
# print("Fruits:", num_fruit)
# print("Vegetables:", num_veg)
# ```
#
# ## Solution
# ```python
# # List of items to categorize
# items = ["apple", "carrot", "durian","tomato","banana", "spinach", "orange", "broccoli"]
# # List of known fruits and vegetables
# known_fruits = ["apple", "banana", "orange"]
# known_vegetables = ["carrot", "spinach", "broccoli"]
#
# num_fruit=num_veg=0
#
# # Read each item and categorize it
# # items length = 8
# for item in items:
#     # All 3 fruits satisfies, apple, banana, orange
#     if item in known_fruits:
#         num_fruit=num_fruit+1
#     # All 3 vegetables satisfies, carrot, spinach, broccoli
#     elif item in known_vegetables:
#         num_veg = num_veg+1
#     else:
#         # Item 'durian' is unknown and will not be categorized.
#         # Item 'tomato' is unknown and will not be categorized.
#         print(f"Item '{item}' is unknown and will not be categorized.")
#
# # Output the categorized lists
# print("Fruits:", num_fruit) # Fruits: 3
# print("Vegetables:", num_veg) # Vegetables: 3
# ```

# %% [markdown]
# # Q7
#
# ## Problem
# Real-Life Example: Simple ATM Transaction
# Let's consider an ATM allow a user to check their balance, deposit money, and withdraw money.
# Partial code is given as follows:
#
# ```python
# # Initialize account balance
# balance = 1000.0
#
# while True:
#     print('''\nATM Menu:)
#                 1. Check Balance
#                 2. Deposit Money
#                 3. Withdraw Money
#                 4. Exit''')
#
#     # Get user choice
# choice = int(input("Enter your choice (1-4): "))
# ```
#
# Please complete the code based on the choices provided by the ATM.
#
# ### Choice 1: Check Balance
# Displays the current balance.
#
# ### Choice 2: Deposit Money
# Prompts the user to enter a deposit amount.
# Checks if the deposit amount is positive.
# Adds the deposit amount to the balance and displays the new balance.
# Displays an error message if the deposit amount is invalid.
#
# ### Choice 3: Withdraw Money
# Prompts the user to enter a withdrawal amount.
# Checks if the withdrawal amount is positive and does not exceed the balance.
# Subtracts the withdrawal amount from the balance and displays the new balance.
# Displays an error message if the withdrawal amount exceeds the balance or is invalid.
#
# ### Choice 4: Exit
# Exits the program and thanks the user.
#
# ### Invalid Choice:
# Displays an error message if the user enters an invalid choice.

# %%
# Initialize account balance
balance = 1000.0

running = True
while running:
    print('''\nATM Menu:)
                1. Check Balance
                2. Deposit Money
                3. Withdraw Money
                4. Exit''')
    
    # Get user choice
    choice = int(input("Enter your choice (1-4): "))

    if choice <= 0 or choice > 4:
        print(f"Invalid choice, '{choice}'.")
        continue 
    
    match (choice):
        # Check balance.
        case 1:
            print(f"You have ${balance:2f}")
        case 2:
            amount = 0
            while True:
                amount = float(input("Enter an amount to deposit: $"))
                if amount < 0:
                    print(f"${amount} is too low, please enter a positive amount.")
                    continue
                break
            balance += amount
            print(f"Deposited ${amount:2f}. You have ${balance:2f}")
        case 3:
            amount = 0
            while True:
                amount = float(input("Enter an amount to deposit: $"))
                if amount < 0:
                    print(f"${amount} is too low, please enter a positive amount.")
                    continue
                break
            balance -= amount
            print(f"Withdrawn ${amount:2f}. You have ${balance:2f}")
        case 4:
            print("Exit.")
            running = False
# Out:
# ATM Menu:)
#                 1. Check Balance
#                 2. Deposit Money
#                 3. Withdraw Money
#                 4. Exit
# You have $1000.000000
#
# ATM Menu:)
#                 1. Check Balance
#                 2. Deposit Money
#                 3. Withdraw Money
#                 4. Exit
# You have $1000.000000
#
# ATM Menu:)
#                 1. Check Balance
#                 2. Deposit Money
#                 3. Withdraw Money
#                 4. Exit
# Deposited $3333333.000000. You have $3334333.000000
#
# ATM Menu:)
#                 1. Check Balance
#                 2. Deposit Money
#                 3. Withdraw Money
#                 4. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 13
#       6 print('''\nATM Menu:)
#       7             1. Check Balance
#       8             2. Deposit Money
# ...
